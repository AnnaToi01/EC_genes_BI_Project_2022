# %% [markdown]
# # Phylogenetic analysis
#
# For phylogenetic analysis we use the file with amino acid FASTA sequences generated in the folder `OrthoGroups_analysis`.
#
# Versions:
# * MUSCLE - v3.8.1551
# * MAFFT - v7.310
# * ClustalO - 1.2.3
# * Ugene - v41
# * [IQ-Tree v2.2.0_beta](https://anaconda.org/bioconda/iqtree)
#
# Coverage is universally bad, but we decided to use ClustalO to build the tree.

# %% [markdown]
# ## MUSCLE

# %%
# !muscle -in conc_protein_seq.fa -out alig_muscle.fa
# Out:
# MUSCLE v3.8.1551 by Robert C. Edgar
#
# http://www.drive5.com/muscle
# This software is donated to the public domain.
# Please cite: Edgar, R.C. Nucleic Acids Res 32(5), 1792-97.
#
#
# *** WARNING *** Invalid character '*' in FASTA sequence data, ignored
#
# *** WARNING *** Invalid character '*' in FASTA sequence data, ignored
#
# *** WARNING *** Invalid character '*' in FASTA sequence data, ignored
#
# *** WARNING *** Invalid character '*' in FASTA sequence data, ignored
#
# *** WARNING *** Invalid character '*' in FASTA sequence data, ignored
#
# *** WARNING *** Invalid character '*' in FASTA sequence data, ignored
#
# *** WARNING *** Invalid character '*' in FASTA sequence data, ignored
#
# *** WARNING *** Invalid character '*' in FASTA sequence data, ignored
#
# *** WARNING *** Invalid character '*' in FASTA sequence data, ignored
#
# *** WARNING *** Invalid character '*' in FASTA sequence data, ignored
#
# *** WARNING *** Invalid character '*' in FASTA sequence data, ignored
#
# ...

# %%
# !head alig_muscle.fa
# Out:
# >Csa16g043530.1_Camelina_sativa Csa16g043530.1 pep chromosome:Cs:16:22269739:22270303:-1 gene:Csa16g043530 transcript:Csa16g043530.1 gene_biotype:protein_coding transcript_biotype:protein_coding
# ---------------------------------MASNTSFLFV--TVTLLLIL-----NV
# SCR-----------------------TLPAA---LA---GS-------------------
# ---TSIAARLTGGG----------LMQ-------------CWDAL-YELNLALTRSFSSS
# -ST-----GRPNL-----------------------------------------------
# -----------APVAVTPLTSLPTIAGRRCL----LLLA-LHLRKPMSSVVSVNLRL---
# ---------PAVLLRLLPLSTFD-------TFSSLIDKDPPNWK----------------
# ------
# >EOY18917_Theobroma_cacao EOY18917 pep chromosome:Theobroma_cacao_20110822:10:6160510:6171885:-1 gene:TCM_043423 transcript:EOY18917 gene_biotype:protein_coding transcript_biotype:protein_coding description:Uncharacterized protein
# -----------------------------------MARKNVFL--LLSMFCLL-----AA

# %% [markdown]
# Alignment coverage as visualized in UGENE.
#
# ![alig_mafft.png](alig_muscle.png)

# %% [markdown]
# ## MAFFT

# %%
# !mafft --auto conc_protein_seq.fa > mafft/alig_mafft.fa
# Out:
# nthread = 0
# stacksize: 8192 kb
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#   201 / 201
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   190 / 201
# done.
#
# Progressive alignment 1/2...
# STEP   198 / 200 d
# Reallocating..done. *alloclen = 1587
# STEP   200 / 200 d
# done.
#
# Making a distance matrix from msa..
#   100 / 201
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   190 / 201
# done.
#
# Progressive alignment 2/2...
# STEP   197 / 200 d
# Reallocating..done. *alloclen = 1576
# STEP   200 / 200 d
# done.
#
# disttbfast (aa) Version 7.310 alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
# dndpre (aa) Version 7.310 alg=X, model=BLOSUM62, 1.53, +0.12, -0.00, noshift, amax=0.0
# 0 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 2
# sueff_global = 0.100000
#
#   190 / 201
# Segment   1/  2    1- 369
# ...

# %%
# !head mafft/alig_mafft.fa
# Out:
# >QL10p018382_mrna_CDS_2_Quercus_lobata QL10p018382:mrna:CDS:2 pep chromosome:ValleyOak3.0:10:18380679:18384186:1 gene:QL10p018382 transcript:QL10p018382:mrna gene_biotype:protein_coding transcript_biotype:protein_coding
# ---------------------------------MAS----------------------QN
# LF-VL-L---SLA-CL-LAMTN--------------------------VTAT-RD-----
# ---LYIK------PGH-----------------------RLAT------------R----
# ------PET-------------S--------S-E-----G-------LVP-CWNAPW-EL
# KSCPNEIVVFF-LN-------------GQTDI----------------------------
# ------------------------------APDCCRAITII-THHCWPA--MLTS-LGFT
# AEEGNILRGYCA----A--E--------------ASV-PST-A-----PPL---------
# GLPL-------------------------P------------------------RA----
# ------------------------

# %% [markdown]
# Alignment coverage as visualized in UGENE.
#
# ![alig_mafft.png](alig_mafft.png)

# %% [markdown]
# # ClustalO

# %% [markdown]
# **1. ClustalO Alignment**

# %%
# !clustalo --infile=conc_protein_seq.fa --outfile=clustalo/alig_clustalo.fa --verbose
# Out:
# Using 8 threads
# Read 201 sequences (type: Protein) from conc_protein_seq.fa
# Using 58 seeds (chosen with constant stride from length sorted seqs) for mBed (from a total of 201 sequences)
# Calculating pairwise ktuple-distances...
# Ktuple-distance calculation progress done. CPU time: 0.78u 0.00s 00:00:00.78 Elapsed: 00:00:00
# mBed created 4 cluster/s (with a minimum of 1 and a soft maximum of 100 sequences each)
# Distance calculation within sub-clusters done. CPU time: 1.04u 0.00s 00:00:01.04 Elapsed: 00:00:00
# Guide-tree computation (mBed) done.
# Progressive alignment progress done. CPU time: 140.25u 0.22s 00:02:20.47 Elapsed: 00:00:21
# Alignment written to clustalo/alig_clustalo.fa

# %%
# !head clustalo/alig_clustalo.fa
# Out:
# >QL10p018382_mrna_CDS_2_Quercus_lobata QL10p018382:mrna:CDS:2 pep chromosome:ValleyOak3.0:10:18380679:18384186:1 gene:QL10p018382 transcript:QL10p018382:mrna gene_bio
# ------------------------------------------------------------
# --------------MA-------SQNLFVLL-----SLACLLAM-----TNVTATRDLY-
# -IKP------------------------------G-HRLATR---PE----TSSEG----
# LVPCWNAPWEL----------------------------------------KSCPNEIVV
# FFLNG-------QTDIAPDCCRAI---TII-THHCWP--AMLTSLGFTAEEGNILRGYCA
# AEASVPSTAP------PLGLPLP--------------------RA---------------
# ------
# >QL06p031114_mrna_CDS_2_Quercus_lobata QL06p031114:mrna:CDS:2 pep chromosome:ValleyOak3.0:6:31112829:31115680:-1 gene:QL06p031114 transcript:QL06p031114:mrna gene_bio
# ------------------------------------------------------------

# %% [markdown]
# Alignment coverage as visualized in UGENE.
#
# ![alig_clustalo.png](alig_clustalo.png)

# %% [markdown]
# **2. Using the ClustalO alignment to build a tree**

# %% [markdown]
# #### IQTREE
#
# * [IQ-Tree v2.2.0_beta](https://anaconda.org/bioconda/iqtree)

# %%
# !iqtree -m MFP -s clustalo/alig_clustalo.fa --prefix clustalo_not_trimmed_iqtree_bootstrap -o ERN08734_Amborella_trichopoda -B 1000 -alrt 1000 -abayes
# Out:
# IQ-TREE multicore version 2.0.3 for Linux 64-bit built Dec 20 2020
# Developed by Bui Quang Minh, Nguyen Lam Tung, Olga Chernomor,
# Heiko Schmidt, Dominik Schrempf, Michael Woodhams.
#
# Host:    AnnaToiThink (AVX512, FMA3, 31 GB RAM)
# Command: iqtree -m MFP -s clustalo/alig_clustalo.fa --prefix clustalo_not_trimmed_iqtree_bootstrap -o ERN08734_Amborella_trichopoda -B 1000 -alrt 1000 -abayes
# Seed:    948223 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Fri May 13 12:24:46 2022
# Kernel:  AVX+FMA - 1 threads (8 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 8 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file clustalo/alig_clustalo.fa ... Fasta format detected
# Alignment most likely contains protein sequences
# Alignment has 201 sequences with 366 columns, 320 distinct patterns
# 225 parsimony-informative, 59 singleton sites, 82 constant sites
# ...
